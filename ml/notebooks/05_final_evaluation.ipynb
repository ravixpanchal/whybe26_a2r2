# %% [markdown]
# # Phase 5 — final untouched-test evaluation
#
# The final table is read from the reproducible report generated by `run_phase5.py`. The test split was evaluated once after model and threshold selection.

# %%
from pathlib import Path
import json
import pandas as pd
ROOT = Path.cwd()
while ROOT != ROOT.parent and not (ROOT / "processed" / "train.csv").exists(): ROOT = ROOT.parent
test_metrics = pd.read_csv(ROOT / "ml" / "reports" / "test_metrics.csv")
metadata = json.loads((ROOT / "ml" / "artifacts" / "model_metadata.json").read_text())
print("Selected model:", metadata["model_name"])
print("Threshold:", metadata["threshold"]["threshold"])
test_metrics
